# %%
#W3A2

# %%
#W3A3
n = int(input("Nhập số n: "))
if n>0 and (n & (n - 1)) == 0:
    print(n,"là lũy thừa của 2")
else:
    print(n,"không phải là lũy thừa của 2")

# %%
a,b,c = map(int,input().split())
if a>b and a>c:
    print("So lon nhat la: ",a)
elif b>c:
    print("So lon nhat là: ",b)
else:
    print("So lan nhat la: ",c)
# Out:
# So lon nhat là:  56

# %%
a,b,c = map(int,input().split())
max_num=a if a > b and a > c else b if b > c else c
print(max_num)
# Out:
# 5

# %%
#W3P4
m,n = map(float,input().split())
g=m // n
print("Ket qua lam tron xuong: ",g)
# Out:
# Ket qua lam tron xuong:  8.0

# %%
#W3P5
m,n = map(float,input().split())
t=(m + n-1) // n
print("Ket qua lam tron len: ",t)
# Out:
# Ket qua lam tron len:  9.0

# %%
#W3P6
x = int(input("Nhap so nguyen:"))
if x > 0:
    if x % 2 == 0:
        print("EVEN")
    else:
        print("ODD")
else:
    print("Khong phai so nguyen duong")
# Out:
# Khong phai so nguyen duong

# %%
#W3P7
a ,b = map(int,input().split())
if a < 0 and b < 0:
    print("YES")
else:
    print("NO")
# Out:
# YES

# %%
#W3P8
a = input("Nhập chuỗi a: ")
b = input("Nhập chuỗi b: ")
if len(a) > len(b):
    print("True")
else:
    print("False")
# Out:
# True

# %%
#W3P9
a ,b ,c = map(int,input().split())
if a > 0 and b > 0 and c > 0:
    if a + b >c and b + c >a and c + a >b:
        print("Day la tam giac")
    else:
        print("Khong phai la tam giac")
else:
    print("LỖI")
# Out:
# Day la tam giac

# %%
#W3P10
a ,b ,c ,d = map(int,input().split())
print("So lon nhat trong 4 so: ",max(a,b,c,d))
# Out:
# So lon nhat trong 4 so:  5

# %%
#W3P11
a ,b ,c = map(int,input().split())
if a > 0 and b > 0 and c > 0:
    if a + b >c and b + c >a and c + a >b:
        print("Day la tam giac")
        if a==b==c:
            print("Tam giac deu")
        elif a==b or b==c or a==c:
            print("Tam giac can")
        elif a**2+b**2==c**2 or c**2+b**2==a**2 or a**2+c**2==b**2 :
            print("Tam giac vuong")
    else:
        print("Khong phai la tam giac")
else:
    print("LỖI")
# Out:
# Day la tam giac
# Tam giac can

# %%
#W3P12
n = int(input("Nhap so nguyen duong: "))
if (n % 4 == 0 and n % 100 != 0) or (n % 400 == 0):
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
#W3P14
a = float(input("Nhap a: "))
b = float(input("Nhap b: "))
if a==0:
    if b==0:
        print("Phuong trinh vo so nghiem")
    else:
        print("Phuong trinh vo nghiem")
else:
    print("Nghiem x=",round(-b/a, 2))
# Out:
# Nghiem x= -2.0

# %%
#W3P15
a=float(input("Nhập điểm trung bình của học sinh:"))
print(a)
if a>=8:
    print("Học lực giỏi")
elif a>=6.5:
    print("Học lực khá")
elif a>=5.0:
    print("Học lực trung bình")
else:
    print("Học lực yếu")
# Out:
# 6.5
# Học lực khá

# %%
#W3P16
x = float(input("Nhập số thực: "))
nguyen = int(x)
if x >= 0:
    floor = nguyen
else:
    floor = nguyen if x == nguyen else nguyen - 1
if x == nguyen:
    ceil = nguyen
else:
    if x > 0:
        ceil = nguyen + 1
    else:
        ceil = nguyen
phan_thap_phan = abs(x - nguyen)
if phan_thap_phan < 0.5:
    round_near = floor
else:
    round_near = ceil

print(floor, ceil, round_near)
# Out:
# 3 4 3

# %%
#W3P17
a ,b ,c ,d = map(int,input().split())
if a != 0 and b % a == 0:
    q = b // a  
    if b * q == c and c * q == d:
        print("Yes")
    else:
        print("No")
else:
    print("No")
# Out:
# Yes
