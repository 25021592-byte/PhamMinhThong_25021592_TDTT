# %%
print("Hello World")
# Out:
# Hello World

# %%
name = input("Ten nguoi nhap:")
print("hello")
# Out:
# hello

# %%
a=int(input("Nhap so nguyen:"))
b=int(input("Nhap so nguyen:"))
tong=a+b
hieu=a-b
tich=a*b
phan_nguyen=a//b
phan_du=a%b
chia_thuc=a/b
print("Tong:",tong)
print("Hieu:",hieu)
print("Tich",tich)
print("Phan nguyen",phan_nguyen)
print("Phan du",phan_du)
print("Chia thuc",format(chia_thuc,".2f"))
# Out:
# Tong: 256
# Hieu: 172
# Tich 8988
# Phan nguyen 5
# Phan du 4
# Chia thuc 5.10
