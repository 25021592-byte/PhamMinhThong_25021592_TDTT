# %%
#Bai 1
print("Hello World")
# Out:
# Hello World

# %%
#Bai 2
name = input("Ten nguoi nhap:")
print("hello")
# Out:
# hello

# %%
#Bai 3
a=int(input("Nhap so nguyen:"))
b=int(input("Nhap so nguyen:"))
tong=a+b
hieu=a-b
tich=a*b
phan_nguyen=a//b
phan_du=a%b
chia_thuc=a/b
print("Tong:",tong)
print("Hieu:",hieu)
print("Tich",tich)
print("Phan nguyen",phan_nguyen)
print("Phan du",phan_du)
print("Chia thuc",format(chia_thuc,".2f"))
# Out:
# Tong: 256
# Hieu: 172
# Tich 8988
# Phan nguyen 5
# Phan du 4
# Chia thuc 5.10

# %%
#Bai 4
a1,b1,c1,a2,b2,a3= map(float,input().split())
print(a1,b1,c1,a2,b2,a3)
TB=((a1+b1+c1)+(a2+b2)*2+a3*3)/10
round(TB,1)
print(TB)
# Out:
# 4.0 5.0 6.0 7.0 9.0 4.0
# 5.9

# %%
#Bai 5
a,b= map(int,input().split())
print(a,b)
s=a**b
print(s)
# Out:
# 4 5
# 1024

# %%
#Bai 6
ki_tu=input("Nhap 1 chu cai thuong:")
print(ki_tu)
print(ord(ki_tu))
print("Chu viet hoa tuong ung:",ki_tu.upper())
# Out:
# t
# 116
# Chu viet hoa tuong ung: T

# %%
#Bai 7
A = ((13**2)*3)+5
B = 13**2*3+5
print("A =",A)
print("B =",B)
# Out:
# A = 512
# B = 512

# %%
#Bai 8
C = float(input("Nhập nhiệt độ (°C): "))
F = 9/5*C+32
print("Nhiệt độ Fahrenheit là:",round(F,2))
# Out:
# Nhiệt độ Fahrenheit là: 113.0

# %%
#Bai 9
x = float(input("Nhập giá chiếc đồng hồ (USD): "))
s=10
phuphi= 0.3*x
vat = 0.1*x
tong= x+phuphi+vat+s
print("Tổng số tiền Sơn Tùng phải trả là:",round(tong, 2),"USD")
# Out:
# Tổng số tiền Sơn Tùng phải trả là: 290.0 USD

# %%
#Baitapthem
a=float(input("Nhập điểm trung bình của học sinh:"))
print(a)
if a>=8:
    print("Học lực giỏi")
elif a>=6.5:
    print("Học lực khá")
elif a>=5.0:
    print("Học lực trung bình")
else:
    print("Học lực yếu")
# Out:
# 7.8
# Học lực khá

# %%
#Bai 10
name=input("Nhap ten:")
# Tách thành danh sách
name_list = name.split()
# Đảo ngược thứ tự
name_list.reverse()
print(f"Hi {name_list[0]}, {name_list[1]} and {name_list[2]}.")
# Out:
# Hi Helen, Alice and Bob.

# %%
#Bai 11
h = int(input("Nhập giờ: "))
m = int(input("Nhập phút: "))
s = h*3600 + m*60
print("Tổng số giây là:",s)
# Out:
# Tổng số giây là: 43440

# %%
#Bai 12
n = int(input("Nhập độ dài cạnh Rubik (n): "))
rubik= 6*(n**2)
print("Số miếng dán cần thiết là:",rubik)
# Out:
# Số miếng dán cần thiết là: 150

# %%
#Bai 13
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
u = (a * b) % 10
print("Hàng đơn vị của tích a * b là:",u)
# Out:
# Hàng đơn vị của tích a * b là: 2

# %%
#Bai 14
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))
a,b = b,a
print("Sau khi hoán đổi:")
print("a =",a)
print("b =",b)
# Out:
# Sau khi hoán đổi:
# a = 5
# b = 4

# %%
#Bai 15
n = int(input("Nhập n: "))
s = 6*n*(n - 1)+1
print("Số sao thứ",n,"là:",s)
# Out:
# Số sao thứ 8 là: 337

# %%
#Bai 16
#Cach 1
print("Spring")
print("Summer")
print("Autumn")
print("Winter")
#Cach 2
print("Spring\nSummer\nAutumn\nWinter")
#Cach 3
print("""Spring
Summer
Autumn
Winter""")
# Out:
# Spring
# Summer
# Autumn
# Winter
# Spring
# Summer
# Autumn
# Winter
# Spring
# Summer
# Autumn
# Winter

# %%
#Bai 17
print("  *  ")
print(" *** ")
print("*****")
# Out:
#   *
#  ***
# *****

# %%
#Bai 18
print("### # #     ### ###\n #  #   #    #   #\n #  #   #    #   #\n #  #   #    #   #\n #  # #      #   #")
# Out:
# ### # #     ### ###
#  #  #   #    #   #
#  #  #   #    #   #
#  #  #   #    #   #
#  #  # #      #   #

# %%
#Bai 19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#Bai 20
print("January\nFebruary\nMatch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# Match
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#Bai 21
for i in range(10):
    print("Hello,world")
# Out:
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
